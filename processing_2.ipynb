# %%
import pandas as pd       #library for working with data sets
import numpy as np        #library for arithematice and statical operations
import seaborn as sns     #library for making bars and grapghs

# %%
df = sns.load_dataset('titanic')    # to load data
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.info()  # to get info of datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  889 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %%
print(df.columns.tolist())  # to print columns
# Out:
# ['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone']

# %%
df['pclass'] # to print particluar column
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
titanic = df[['survived','pclass','sex','age','sibsp','parch','fare','embark_town','alone','deck']].copy() #to copy selected columns

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  embark_town  \
# 0           0       3    male  22.0      1      0   7.2500  Southampton
# 1           1       1  female  38.0      1      0  71.2833    Cherbourg
# 2           1       3  female  26.0      0      0   7.9250  Southampton
# 3           1       1  female  35.0      1      0  53.1000  Southampton
# 4           0       3    male  35.0      0      0   8.0500  Southampton
# ..        ...     ...     ...   ...    ...    ...      ...          ...
# 886         0       2    male  27.0      0      0  13.0000  Southampton
# 887         1       1  female  19.0      0      0  30.0000  Southampton
# 888         0       3  female   NaN      1      2  23.4500  Southampton
# 889         1       1    male  26.0      0      0  30.0000    Cherbourg
# 890         0       3    male  32.0      0      0   7.7500   Queenstown
#
#      alone deck
# 0    False  NaN
# 1    False    C
# 2     True  NaN
# 3    False    C
# ...

# %%
titanic.isnull().sum().plot(kind='pie', figsize = (8,3), autopct='%1f%%') # for piechart representation.
# Out:
# <Axes: >

# %%
titanic.isnull().sum().plot(kind='bar', figsize = (8,3)),#autopct='%1f%%')
# Out:
# (<Axes: >,)

# %%
df.drop(columns=['deck'], inplace=True)# to remove column

# %% [markdown]
# FIXING MISSING Value
#
# NUMERIC MEAN
# CATEGORICAL MEAN

# %%
avg_age = round(titanic['age'].mean())    # find mean
print(f'Average age:{avg_age:.1f}')   #question what is .1f for????
# Out:
# Average age:30.0

# %%
titanic['age'].fillna(avg_age,inplace=True) #.fillna replaces NaN values with 0

# %% [markdown]
# most_frequent_embark_town

# %%
titanic['embark_town'].value_counts().idxmax()  # to find most frequent value
# Out:
# 'Southampton'

# %%
most_freq_embark_town = titanic['embark_town'].value_counts().idxmax()
titanic['embark_town'].fillna(most_freq_embark_town,inplace=True)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  embark_town  \
# 0           0       3    male  22.0      1      0   7.2500  Southampton
# 495         0       3    male  30.0      0      0  14.4583    Cherbourg
# 536         0       1    male  45.0      0      0  26.5500  Southampton
# 538         0       3    male  30.0      0      0  14.5000  Southampton
# 543         1       2    male  32.0      1      0  26.0000  Southampton
# ..        ...     ...     ...   ...    ...    ...      ...          ...
# 257         1       1  female  30.0      0      0  86.5000  Southampton
# 678         0       3  female  43.0      1      6  46.9000  Southampton
# 677         1       3  female  18.0      0      0   9.8417  Southampton
# 448         1       3  female   5.0      2      1  19.2583    Cherbourg
# 520         1       1  female  30.0      0      0  93.5000  Southampton
#
#      alone deck
# 0    False  NaN
# 495   True  NaN
# 536   True    B
# 538   True  NaN
# ...

# %%
titanic['survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
titanic['age'].value_counts()
# Out:
# 30.00    202
# 24.00     30
# 22.00     27
# 18.00     26
# 28.00     25
#         ...
# 36.50      1
# 55.50      1
# 0.92       1
# 23.50      1
# 74.00      1
# Name: age, Length: 88, dtype: int64

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embark_town      0
# alone            0
# deck           688
# dtype: int64

# %% [markdown]
# selection of columns based on data type

# %%
#only numerical column from titanic dataframe
df.select_dtypes(include=object)
# Out:
#         sex embarked    who  embark_town alive
# 0      male        S    man  Southampton    no
# 1    female        C  woman    Cherbourg   yes
# 2    female        S  woman  Southampton   yes
# 3    female        S  woman  Southampton   yes
# 4      male        S    man  Southampton    no
# ..      ...      ...    ...          ...   ...
# 886    male        S    man  Southampton    no
# 887  female        S  woman  Southampton   yes
# 888  female        S  woman  Southampton    no
# 889    male        C    man    Cherbourg   yes
# 890    male        Q    man   Queenstown    no
#
# [891 rows x 5 columns]

# %%
titanic.select_dtypes(include=np.number)
# Out:
#      survived  pclass   age  sibsp  parch     fare
# 0           0       3  22.0      1      0   7.2500
# 1           1       1  38.0      1      0  71.2833
# 2           1       3  26.0      0      0   7.9250
# 3           1       1  35.0      1      0  53.1000
# 4           0       3  35.0      0      0   8.0500
# ..        ...     ...   ...    ...    ...      ...
# 886         0       2  27.0      0      0  13.0000
# 887         1       1  19.0      0      0  30.0000
# 888         0       3  30.0      1      2  23.4500
# 889         1       1  26.0      0      0  30.0000
# 890         0       3  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
titanic.select_dtypes(include=bool)
# Out:
#      alone
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# ..     ...
# 886   True
# 887   True
# 888  False
# 889   True
# 890   True
#
# [891 rows x 1 columns]

# %% [markdown]
# describing data in terms of mean, median, mode,standard deviation ,min,max.etc

# %%
titanic.describe
# Out:
# <bound method NDFrame.describe of      survived  pclass     sex   age  sibsp  parch     fare  embark_town  \
# 0           0       3    male  22.0      1      0   7.2500  Southampton
# 1           1       1  female  38.0      1      0  71.2833    Cherbourg
# 2           1       3  female  26.0      0      0   7.9250  Southampton
# 3           1       1  female  35.0      1      0  53.1000  Southampton
# 4           0       3    male  35.0      0      0   8.0500  Southampton
# ..        ...     ...     ...   ...    ...    ...      ...          ...
# 886         0       2    male  27.0      0      0  13.0000  Southampton
# 887         1       1  female  19.0      0      0  30.0000  Southampton
# 888         0       3  female  30.0      1      2  23.4500  Southampton
# 889         1       1    male  26.0      0      0  30.0000    Cherbourg
# 890         0       3    male  32.0      0      0   7.7500   Queenstown
#
#      alone deck
# 0    False  NaN
# 1    False    C
# 2     True  NaN
# ...

# %%
titanic.describe(include=object)
# Out:
#          sex  embark_town
# count    891          891
# unique     2            3
# top     male  Southampton
# freq     577          646

# %%
titanic.describe(include=[object,bool])
# Out:
#          sex  embark_town alone
# count    891          891   891
# unique     2            3     2
# top     male  Southampton  True
# freq     577          646   537

# %%
titanic.groupby(['pclass','survived'],as_index=False)['survived'].count()
# Out:
#    pclass  survived
# 0       1        80
# 1       1       136
# 2       2        97
# 3       2        87
# 4       3       372
# 5       3       119

# %%
titanic.groupby(['sex','survived'],as_index=False)['survived'].count()
# Out:
#       sex  survived
# 0  female        81
# 1  female       233
# 2    male       468
# 3    male       109

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
titanic.sort_values(by='sex', ascending=False,inplace=True)
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  embark_town  \
# 0           0       3    male  22.0      1      0   7.2500  Southampton
# 495         0       3    male  30.0      0      0  14.4583    Cherbourg
# 536         0       1    male  45.0      0      0  26.5500  Southampton
# 538         0       3    male  30.0      0      0  14.5000  Southampton
# 543         1       2    male  32.0      1      0  26.0000  Southampton
# ..        ...     ...     ...   ...    ...    ...      ...          ...
# 257         1       1  female  30.0      0      0  86.5000  Southampton
# 678         0       3  female  43.0      1      6  46.9000  Southampton
# 677         1       3  female  18.0      0      0   9.8417  Southampton
# 448         1       3  female   5.0      2      1  19.2583    Cherbourg
# 520         1       1  female  30.0      0      0  93.5000  Southampton
#
#      alone deck
# 0    False  NaN
# 495   True  NaN
# 536   True    B
# 538   True  NaN
# ...
